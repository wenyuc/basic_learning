# %% [markdown]
# https://www.youtube.com/watch?v=b9a27XN_6tg

# %% [markdown]
# Notation to describe the distribution
#
# $ X \sim N(\mu, \sigma^2) $

# %% [markdown]
# **Poisson Distribution**
#
# Test out how unusual on event frequency is for a given interval.
#
# **Normal Distribution**
#   **Student-T Distribution**
#
# **Chi-Squared** (Kai)
# - Asymmetric
# - Only consists of non-negative values
# - The Chi-Squared does not often mirror real life events
#     - However, it is often used in Hypothesis Testing to help determine goodness of fit.

# %% [markdown]
# **Probability Distribution Function**
# https://www.youtube.com/watch?v=YXLVjCKVP7U
#
#
# Discrete  ： Probability mass function （PMF）
# Continuous： Probability density function (PDF)
#
# Together: Cumulative distribution function （CDF）
#
# ##### Discrete
# $ P(X \leq 4) = P(X = 1)+ P(X = 2)+ P(X = 3)+ P(X = 4) $
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #####  Continuous
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #####  The relationship between PDF and CDF
#
# ![image-3.png](attachment:image-3.png)
