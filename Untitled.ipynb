# %%
import pandas as pd

s = pd.Series([,])
s.T
# Out:
# 0       9
# 1      80
# 2      32
# 3      96
# 4      32
#        ..
# 539     0
# 540    55
# 541    47
# 542     0
# 543    10
# Length: 544, dtype: int64
