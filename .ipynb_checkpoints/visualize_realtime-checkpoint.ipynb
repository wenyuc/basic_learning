# %% [markdown]
# https://www.youtube.com/watch?v=GIywmJbGH-8

# %%
import time
import psutil
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
psutil.cpu_percent()
# Out:
# 1.7

# %%
i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    
    ax.plot(x, y, color = 'b')
    fig.canvas.draw()
    ax.set_xlim(left =max(0, i-50), right = i+ 50)
    time.sleep(0.1)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6374dfe6f167> in <module>
#       9     fig.canvas.draw()
#      10     ax.set_xlim(left =max(0, i-50), right = i+ 50)
# ---> 11     time.sleep(0.1)
#      12     i += 1
#
# KeyboardInterrupt:

# %%
plt.close()
