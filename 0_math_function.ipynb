# %% [markdown]
# ##### Bayes Function
#
# $ P(A \mid B) = \frac {P(B \mid A)P(A)}{P(B)} $

# %% [markdown]
# ##### Bayes Function
# $$ P(A \mid B) = \frac {P(B \mid A)P(A)}{P(B)} $$

# %% [markdown]
# ##### White space
# > 通过 \ \: |; 添加空格
#
# $$ \int f(x) \;dx$$
#
# $$ \int_{0}^{\pi}{\sin{x}\;dx} $$

# %% [markdown]
# ##### 上标和下标
#
# $ x^2 $
#
# $ x_i^2 $
#
# $ x_{ij}^3 $
#
# $ e^2x $
#
# $ (log \; x)^2 $
#
# $ e^{2x} $
#
# $ e^ {\frac {1}{3}x} $
#
# $ e_{(i)}^{(m) \ 2} $
#
# $ C_{10}^{5} $
#
# $ \binom{n}{k}$
#
# $ \underset{k}argmax \ f(x_k) $

# %% [markdown]
# ##### 命令
# 特定的符号和形式通过命令进行编写，每一个命令以反斜杠开始，一个命令名紧随其后。
#
# $ \sqrt{2\pi} $
#
# $ \sqrt[3]{2x} $
#
# $ \frac{a}{b} $
#
# $ \cfrac{a}{c} $
#
# $ \cfrac{1}{3} - \cfrac{x_i^2}{y_j^3} $
#
# $ \log_{a}^{\;b}\;\lg\;\ln $
#
# $ \bot\;\angle\;30^\circ\;\sin\;\cos\;\tan\;\cot\;\sec\;\csc\;\arctan\;\cosh $
#
# $ f\prime {(x)} \; \int\;\iint\;\iiint\;\iiiint\;\oint\;$
#
# $ \cfrac{\partial^{2}y}{\partial x^{2}} $
#
# > 有时要用\left. 或 \right. 进行匹配而不显示其本身
#
# $  \left. \cfrac{ {\rm d} u}{ {\rm d} x} \right| _{x=0} $
#
# $ \because\;\therefore\;\forall\;\exists\;\not=\;\not> $

# %% [markdown]
# ##### 希腊字母符号
#
# $ \alpha  \; \beta  \;  \gamma  \;  \delta  \;  \epsilon  \;  \varepsilon  \; \zeta $
#
# $ \eta  \; \theta  \;  \vartheta  \;  \iota  \;  \kappa  \;  \lambda  \;  \mu  $
#
# $  \nu  \;  \xi  \;  \pi  \;  \varpi  \;  \rho  \;  \varrho  \;  \sigma  \; \varsigma  $
#
# $  \tau  \;  \upsilon  \;  \phi  \;  \varphi  \;  \chi  \;  \psi  \;  \omega   $
#
# Uppercase
#
# $  \Gamma  \;  \Delta  \;  \Theta  \;  \Lambda   \;  \Xi \; \Pi \; \Sigma \; \Upsilon\;\Phi \; \Psi  \;  \Omega $

# %% [markdown]
# ##### 一些计算符号
#
# $ \times\;\pm\;\oplus\;\div\;\mid\;\nmid\;\cdot\;\circ\;\ast $
#
# $ \odot\;\bigodot\;\otimes\;\bigotimes\;\oplus\;\bigoplus $
#
# $ \emptyset\;\cap\;\cup\;\vee\;\wedge\;\bigcap\;\bigcup\;\bigvee\;\bigwedge\;\biguplus\;\bigsqcup $
#
# $ <\;\not<\;\leq\;\ll\;\subset\;\not\subset\;\subseteq\;\nsubseteq\;\sqsubset\;\sqsubseteq\;\preceq$
#
# $ >\;\not>\;\geq\;\gg\;\supset\;\not\supset\;\supseteq\;\nsupseteq\;\sqsupset\;\sqsupseteq\;\succeq$
#
# $ =\;\doteq\;\equiv\;\approx\;\cong\;\simeq\;\sim\;\propto\;\neq $
#
# $ \parallel\;\asymp\;\vdash\;\in\;\smile\;\models\;\perp\;\prec\;\sphericalangle $
#
# $ \nparallel\;\bowtie\;\dashv\;\ni\;\frown\;\notin\;\mid\;\succ\;\measuredangle $
#
# $ \infty\;\nabla\;\partial $
#
# $ X \sim N(\mu, \sigma^2) $
# > \ldots 与底线对齐的省略号 ； \cdots 与中线对齐的省略号
#
# $ f(x_1, x_2, \ldots , x_n) = x_1 + x_2 + \cdots + x_n $
#
# $ f(x_1, x_2, \ldots , x_n) = x_1 \times x_2 \times \cdots \times x_n $
#
# $ \underbrace{x_1+x_2+\cdots+x_{10}}_{10} $
#
# $ \overbrace{x_1+x_2+\cdots+x_{10}}^{10} $
#
# > \cdot可以表示点积
#
# $ \boldsymbol{A \cdot x} = \lambda \cdot v $
#
# $ \uparrow\;\downarrow\;\Uparrow\;\Downarrow $
#
# $ \rightarrow\;\longrightarrow\;\Rightarrow\;\Longrightarrow\;\leftarrow\;\longleftarrow\;\Leftarrow\;\Longleftarrow $
#
# $\Rightarrow[easy]{就是这样子啦}$

# %% [markdown]
# ##### 省略号
#
# $\cdots \; \ddots \; \dotsb \; \dotsc \; \dotsi $
#
# $\dotsm \; \dotso \; \ldots \; \vdots $
#
# \reflectbox {$\ddots$}

# %% [markdown]
# ##### 头标 和底标
#
# $ \hat x\; \check {y} \; \breve {y} \; \acute y\; \tilde \alpha \; \widetilde \alpha$
#
# $ \hat f(x) $
#
# $ \widehat {f(x)} $
#
# $ \bar x $
#
# $ \tilde N $
#
# $ \overline {f(x)} $
#
# $ \overline{abs} $
#
# $ \underline{abs} $
#
# $ \dot x \; \ddot x $
#
# $ \vec{x} \; \vec{AB} \; \overrightarrow {AB} $
#
# $ \overleftarrow{AB} $

# %% [markdown]
# ##### 括号
#
# $ z = (\frac{dx}{dy})^{\frac{1}{3}} $
#
# $ z = \left(\frac{dx}{dy}\right)^{\frac{1}{3}} $
#
# $ {\langle} {\phi} \mid {\psi} {\rangle} $
#
# $ {\langle} {\phi} \vert {\psi} {\rangle} $
#
# $ \lceil A,B,C \rceil $
#
# $ \lfloor D,E,F \rfloor $
#
# $ \lbrace G,H,I \rbrace $
#
# $p=\left\{
# \begin{aligned}
# x & = & \cos(t) \\
# y & = & \sin(t) \\
# z & = & \frac xy
# \end{aligned}
# \right. $
#
# $ \boxed {x^2 + y^2 = z^2} $

# %% [markdown]
# ##### Matrix
#
# $ \left[\begin{matrix}a & b & c \cr d & e & f \end{matrix} \right] $
#
# $ \left[\begin{matrix}a & b & \cdots & c \cr d & e & \cdots & f \cr \vdots & \vdots & \ddots & \vdots \cr g & h & \cdots & i\end{matrix} \right] $
#
# $ \left\lgroup\begin{matrix}a & b & c \cr d & e & f \end{matrix}\right\rgroup $
#
# **参考资料**
#
# https://blog.csdn.net/nuoyanli/article/details/96179976?ops_request_misc=&request_id=&biz_id=102&utm_term=markdown%20%E6%95%B0%E5%AD%A6%E5%85%AC%E5%BC%8F%E7%9F%A9%E9%98%B5&utm_medium=distribute.pc_search_result.none-task-blog-2~all~sobaiduweb~default-0-.first_rank_v2_pc_rank_v29&spm=1018.2226.3001.4187

# %% [markdown]
# ##### 字体
# 非斜体罗马字符
#
# $ \textrm{abcdefghijklmn123456} $
#
# $ \rm{abcdefghijklmn123456} $
#
# 斜体罗马字符
#
# $ \mathit{abcdefghijklmn123456} $
#
# 加粗罗马字符
#
# $ \mathbf{abcdefghijklmn123456} $
#
# 加粗斜体罗马字符
#
# $ \boldsymbol{abcdefghijklmn123456} $
#
# 意大利体
#
# $ \it{abcdefghijklmn123456} $
#
# 花体
#
# $ \cal{XYZABCDEFGHIJKLMNOPQRSTUVW123456} $
#
# 等线体
#
# $ \sf{abcdefghijklmn123456} $
#
# 打字机体
#
# $ \tt{abcdefghijklmn123456} $

# %% [markdown]
# ##### 对齐
#
# > 通过\断开两个或多个等式，可实现等式中部对齐
#
# $$ a_1 = b_1 + c_1 \\
# a_2 = b_2 + c_2 + d_2 \\
# a_3 = b_3 + c_3 $$
#
# > 左对齐：
#
# $$ \begin{aligned}
# a_1&= b_1 + c_1 \\
# a_2&= b_2 + c_2 + d_2 \\
# a_3&= b_3 + c_3
# \end{aligned} $$

# %% [markdown]
# ##### 分段函数
#
# $$
# sign(x) =
# \begin{cases}
# 1,&x>0 \\
# 0,&x=0 \\
# -1,&x<0
# \end{cases}
# $$

# %% [markdown]
# ##### 一元二次方程求解公式
#
# $ \frac{-b\pm\sqrt{b^2-4ac}}{2a} $

# %% [markdown]
# ##### 求和求积
#
# $ \sum_{0}^{N}{i} $
#
# $ \prod_{1}^{N}{i} $
#
# $ \coprod_{1}^{N}{i} $

# %% [markdown]
# ##### 极限
#
# $ \lim_{n \to +\infty} \cfrac{1}{n(n+1)} $
#
# $ \lim_{n \leftarrow +\infty}\cfrac{1}{n(n+1)} $

# %% [markdown]
# ##### 公式例子
#
# $$ loss = \frac{1}{n}\sum{(y_i)\;-\;{\hat y_i}} $$
#
# $$ f(x,y) = \sum_{i,j=0}^n{\left(x_i^2 + y_j^3\right)} $$
#
# $$ g(x) = \prod_{i=0}^n{\frac{1}{x_i^2}} $$
#
# Binomial Distribution - Probability Density Function
# $$ P(X=x) = C_{n}^{x} p^x (1-p)^{n-x} $$
#
# One-Dimensional Normal Distribution - Probability Density Function
#
# $$ f(x) = \cfrac{1}{\sqrt{2\pi}\sigma}exp{\left(-\cfrac{(x-\mu)^2}{2\sigma^2}\right) } $$
#
# Standard Normal Distribution ($ \mu=0, \sigma=1 )$- Probability Density Function
#
# $$ f(x) = \cfrac{1}{\sqrt{2\pi}}exp{\left(-\cfrac{x^2}{2}\right) } $$

# %% [markdown]
# ##### 例子
# ![0d3474dc73f25490e4c401d8f84851b5.png](attachment:0d3474dc73f25490e4c401d8f84851b5.png)![image.png](attachment:image.png)

# %% [markdown]
# ##### 参考资料
#
# https://blog.csdn.net/qq_37375427/article/details/92198332?ops_request_misc=%257B%2522request%255Fid%2522%253A%2522162313755816780262546451%2522%252C%2522scm%2522%253A%252220140713.130102334.pc%255Fall.%2522%257D&request_id=162313755816780262546451&biz_id=0&utm_medium=distribute.pc_search_result.none-task-blog-2~all~first_rank_v2~rank_v29-5-92198332.first_rank_v2_pc_rank_v29&utm_term=markdown+%E5%9C%86%E5%9C%88%E6%95%B0%E5%AD%97&spm=1018.2226.3001.4187
