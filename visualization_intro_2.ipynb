# %% [markdown]
# https://www.youtube.com/watch?v=MbKrSmoMads

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1. simple plot with 4 numbers

# %%
plt.plot([1,3,2,4])
plt.show()

# %% [markdown]
# # 2. points have x and y values, add title and axis labels

# %%
plt.plot([1,2,3,4], [1,4,9, 16])
plt.title("Test Plot", fontsize = 8, color = 'g')
plt.xlabel('number n')
plt.ylabel('n^2')
plt.show()

# %%
# x = np.linspace(-10, 10, 1000)
# y = 5 * x^4 - 3 * x^3 + 6 * x +10
# plt.plot(X, Y)

# %% [markdown]
# # 3. change figure size, plot red dots, set axis scales x: 0-6 and y: 0-20

# %%
plt.figure(figsize = (2,5))
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0,20])
plt.annotate('square it', (3,6))
plt.show()

# %% [markdown]
# # 4. Bar chart with four bars

# %%
plt.clf()    # clear figure
x = np.arange(4)
y = x ** 2 + 1
plt.xticks(x, ('Ankit', 'Hans', 'Joe', 'Flanc'))
plt.bar(x, y, color = ['lime', 'r', 'k', 'tan'])
plt.show()

# %% [markdown]
# # 5. Two sets of 10 random dots plotted

# %%
d = {'Red O': np.random.rand(10),
    'Grn X': np.random.rand(10)}
df = pd.DataFrame(d)
df.plot(style = ['ro', 'gx'])
plt.legend()
plt.show()

# %% [markdown]
# # 6. Time series - six months of random floats

# %%
ts = pd.Series(np.random.randn(182), 
              index = pd.date_range('1/1/2020', periods = 182))
df = pd.DataFrame(np.random.randn(182, 3), index= ts.index,
                  columns = list('ABC'))
df.cumsum().plot()
plt.show()

# %% [markdown]
# # 7. Draw Quadratics

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn-deep')
x = np.linspace(-20, 20, 1000)
y = [2 * i**2 -5* i + 4 for i in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Draw polynominals

# %%
x = np.linspace(-30, 30, 2000)
y1 = [i**6 for i in x]
y2 = [i**5 for i in x]
y3 = [i**4 for i in x]
y4 = [i**3 for i in x]
y5 = [i**2 for i in x]
y6 = [i for i in x]

plt.plot(x, y1, color = 'r', label = 'x^6')
plt.plot(x, y2, color = 'g', label = 'x^5')
plt.plot(x, y3, color = 'b', label = 'x^4')
plt.plot(x, y4, color = 'black', label = 'x^3')
plt.plot(x, y5, color = 'k', label = 'x^2')
plt.plot(x, y6, color = 'tan', label = 'x')

plt.legend()
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
x = np.linspace(-30, 30, 2000)
y1 = [i for i in x]

ax = plt.axes()
ax.plot(x, y1, '-r')
ax.set(xlim = (-35, 35), ylim = (-40, 40), xlabel = 'X', ylabel ='Y',
      title ='x')
# Out:
# [(-40, 40),
#  Text(0, 0.5, 'Y'),
#  (-35, 35),
#  Text(0.5, 0, 'X'),
#  Text(0.5, 1.0, 'x')]

# %%
plt.style.use('seaborn-whitegrid')
x = np.linspace(-30, 30, 2000)
y2 = [i**2 for i in x]

ax = plt.axes()
ax.plot(x, y2, '-g', label = 'x^2')
ax.set(xlim = (-35, 35), ylim = (-10, 1000), xlabel = 'X', ylabel ='Y',
      title ='x^2')

plt.legend()
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
x = np.linspace(-30, 30, 2000)
y3 = [i**3 for i in x]

ax = plt.axes()
ax.plot(x, y3, '-g')
ax.set(xlim = (-35, 35), ylim = (-10000, 10000), xlabel = 'X', ylabel ='Y',
      title ='x^3')
# Out:
# [(-10000, 10000),
#  Text(0, 0.5, 'Y'),
#  (-35, 35),
#  Text(0.5, 0, 'X'),
#  Text(0.5, 1.0, 'x^3')]

# %%
plt.style.use('seaborn-whitegrid')
x = np.linspace(-30, 30, 2000)
y4 = [i**4 for i in x]

ax = plt.axes()
ax.plot(x, y4, '-b', label = 'x^4')
ax.set(xlim = (-35, 35), ylim = (-10, 100000), xlabel = 'X', ylabel ='Y',
      title ='x^4')

plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,5))
plt.style.use('seaborn-whitegrid')
x = np.linspace(-30, 30, 2000)
y5 = [i**5 for i in x]

ax = plt.axes()
ax.plot(x, y5, '-b', label = 'x^4')
ax.set(xlim = (-35, 35), ylim = (-100000, 100000), xlabel = 'X', ylabel ='Y',
      title ='x^5')

plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,5))
plt.style.use('seaborn-whitegrid')
x = np.linspace(-20, 20, 2000)
y = [5*i**4 - 4*i**3 +10 for i in x]

ax = plt.axes()
ax.plot(x, y, '-r', label = '5*x^4 - 4*x^3 +10')
ax.set(xlim = (-25, 25), ylim = (-100, 1000), xlabel = 'X', ylabel ='Y',
      title ='5*x^4 - 4*x^3 +10')

plt.legend()
plt.show()

# %% [markdown]
# # 7. Random dots in a scatter

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sizes = (30 * np.random.rand(N)) ** 2   # 0 to 15 point radii
plt.scatter(x, y, s = sizes, c = colors, alpha = 0.5)  # alpha is transparency
plt.show()

# %% [markdown]
# # 9. Subplots, part 1
#
# 221 = top left subplot
#
# 222 = top right subplot
#
# 223 = bottom left subplot
#
# 224 = bottom right subplot

# %%
fig = plt.figure()
fig.suptitle('My Subplots')
fig.add_subplot(221)
plt.plot([np.log(n) for n in range(1, 10)])
fig.add_subplot(222, facecolor = 'y')
fig.add_subplot(223)
fig.add_subplot(224)

# %% [markdown]
# ## part 2

# %%
fig,plots = plt.subplots(2, sharex = True)
fig.suptitle('Sharing x axis')
x = range(1, 200, 5)
y = [n ** 0.8 for n in x]
plots[0].plot(x, y, color = 'r')
plots[1].scatter(x, y)
plt.show()

# %% [markdown]
# # Boxplot
# ![image.png](attachment:image.png)
#
# Boxplot 图分为两部分，分别是箱(box) 和须(whisker)。 箱(box)用来表示从第一分位到第三分为的数据，须(whisker)用来表示数据的范围。
# Interquartile range (IQR) = upper quartile - lower quartile
# 四分位间距 = 上分位数 - 下分位数

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(2)
df = pd.DataFrame(np.random.rand(5,4), columns = ['A', 'B', 'C', 'D'])
print(df)
print(df.describe())
print(df.median(axis = 0))

plt.figure()
# _ = plt.boxplot([df['A'], df['B'], df['C'], df['D']], whis = 'range')
# _ = plt.boxplot([df['A'], df['B'], df['C'], df['D']], patch_artist = True , whis = 'range')
# _ = plt.boxplot([df['A'], df['B'], df['C'], df['D']], sym = 'r*', showmeans = True,whis = 'range')
f = plt.boxplot(df['A'], sym = 'r*', showmeans = True, whis = 'range')
for box in f['boxes']:
    # 箱体边框颜色
    box.set(color='#7570b3', linewidth=2)
    # 箱体内部填充颜色
    box.set(facecolor = '#1b9e77')
for whisker in f['whiskers']:
    whisker.set(color='r', linewidth=2)
for cap in f['caps']:
    cap.set(color='g', linewidth=3)
for median in f['medians']:
    median.set(color='DarkBlue', linewidth=3)
for flier in f['fliers']:
    flier.set(marker='o', color='y', alpha=0.5)
plt.show()
# Out:
#           A         B         C         D
# 0  0.435995  0.025926  0.549662  0.435322
# 1  0.420368  0.330335  0.204649  0.619271
# 2  0.299655  0.266827  0.621134  0.529142
# 3  0.134580  0.513578  0.184440  0.785335
# 4  0.853975  0.494237  0.846561  0.079645
#               A         B         C         D
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.428915  0.326181  0.481289  0.489743
# std    0.266524  0.198150  0.283859  0.263081
# min    0.134580  0.025926  0.184440  0.079645
# 25%    0.299655  0.266827  0.204649  0.435322
# 50%    0.420368  0.330335  0.549662  0.529142
# 75%    0.435995  0.494237  0.621134  0.619271
# max    0.853975  0.513578  0.846561  0.785335
# A    0.420368
# B    0.330335
# C    0.549662
# D    0.529142
# dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-ce87950e1e2b> in <module>
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(2)
df = pd.DataFrame(np.random.rand(5,4), columns = ['A', 'B', 'C', 'D'])
print(df)
print(df.describe())
print(df.median(axis = 0))

f = df.boxplot(sym = 'o',            #异常点形状
               vert = True,          # 是否垂直
               whis=1.5,             # IQR
               patch_artist = True,  # 上下四分位框是否填充
               meanline = False,showmeans = True,  # 是否有均值线及其形状
               showbox = True,   # 是否显示箱线
               showfliers = True,  #是否显示异常值
               notch = False,    # 中间箱体是否缺口
               return_type='dict')  # 返回类型为字典
plt.title('Box Plot')
plt.show()
# Out:
#           A         B         C         D
# 0  0.435995  0.025926  0.549662  0.435322
# 1  0.420368  0.330335  0.204649  0.619271
# 2  0.299655  0.266827  0.621134  0.529142
# 3  0.134580  0.513578  0.184440  0.785335
# 4  0.853975  0.494237  0.846561  0.079645
#               A         B         C         D
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.428915  0.326181  0.481289  0.489743
# std    0.266524  0.198150  0.283859  0.263081
# min    0.134580  0.025926  0.184440  0.079645
# 25%    0.299655  0.266827  0.204649  0.435322
# 50%    0.420368  0.330335  0.549662  0.529142
# 75%    0.435995  0.494237  0.621134  0.619271
# max    0.853975  0.513578  0.846561  0.785335
# A    0.420368
# B    0.330335
# C    0.549662
# D    0.529142
# dtype: float64
